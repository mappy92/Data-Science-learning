# %% [markdown]
# # MatplotLib Tutorial
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
## Simple Examples

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##plotting using matplotlib 

##plt scatter

plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %%
y=x*x

# %%
## plt plot

plt.plot(x,y,'g*',linestyle='dashed',linewidth=2, markersize=12)
##plt.plot(x,y,'go--')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
## Creating Subplots

plt.subplot(2,2,1) # nrows, ncols, position
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) ## 0 to 4 * 180 degrees and step size is 0.1
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)
y_sin_cos_square = np.sin(x)*np.sin(x) +  np.cos(x)*np.cos(x)
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(3, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(3, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  

# Set the third subplot as active, and make the third plot. 
plt.subplot(3, 1, 3) 
plt.plot(x, y_sin_cos_square,'b--') 
plt.title('Square formula')  
   
# Show the figure. 
plt.show()

# %%
x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a) # default bins are 10 & the first bar tells us that there are 3 numbers present in our dataset from 0-10 range
plt.title("histogram") 
plt.show()

# %% [markdown]
# ## Box Plot using Matplotlib

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %%
data
# Out:
# [array([ 1.77965166, -1.69756576, -0.35496789,  0.44530162,  2.266161  ,
#         -0.48587003,  2.65000735, -0.6171009 , -1.28225977, -0.03131681,
#         -0.31287344,  0.256299  ,  1.82908346, -0.48140963,  0.81079099,
#          0.10828181, -1.28501553, -0.5816692 ,  0.97591089,  0.11439029,
#         -1.50833664,  0.43184678, -0.84970823, -0.27438001, -1.43892661,
#          0.7104065 , -0.50161208, -0.43272401, -0.62230223,  0.22140194,
#         -0.9737662 ,  0.30708086, -0.65998043, -0.21176068, -0.60576588,
#         -0.69214017, -1.44491157,  0.12996557, -0.37723936,  0.96519671,
#         -1.46654904, -1.29677822, -0.59408924,  1.73235346, -0.35387264,
#         -1.16933727,  1.18989378, -1.90320319,  1.03276532, -0.58009093,
#         -1.3071216 , -0.14316261, -0.22981067, -0.17227524, -1.84420636,
#          1.17561057, -1.90093726,  1.06589128,  0.0931872 , -1.04131305,
#         -1.74176353,  1.92858731, -1.21209233,  2.39575213,  0.58271123,
# ...

# %% [markdown]
# ## Pie Chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.2f%%', shadow=True)

plt.axis('equal')
plt.show()
