# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in c:\users\manpr\anaconda3\lib\site-packages (0.2.16)
# Requirement already satisfied: click in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (8.2.1)
# Requirement already satisfied: scikit-learn in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: pandas in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (2.3.2)
# Requirement already satisfied: tqdm in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (1.5.2)
# Requirement already satisfied: lightgbm in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (4.6.0)
# Requirement already satisfied: xgboost in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: pytest-runner in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (6.0.1)
# Requirement already satisfied: mlflow>=2.0.0 in c:\users\manpr\anaconda3\lib\site-packages (from lazypredict) (3.3.2)
# Requirement already satisfied: mlflow-skinny==3.3.2 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (3.3.2)
# Requirement already satisfied: mlflow-tracing==3.3.2 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (3.3.2)
# Requirement already satisfied: Flask<4 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (2.3.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (1.16.5)
# Requirement already satisfied: cryptography<46,>=43.0.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (3.4.3)
# Requirement already satisfied: matplotlib<4 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (3.10.0)
# Requirement already satisfied: numpy<3 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (1.26.4)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (21.0.0)
# Requirement already satisfied: scipy<2 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (2.0.34)
# Requirement already satisfied: waitress<4 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (5.5.2)
# Requirement already satisfied: cloudpickle<4 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.65.0)
# Requirement already satisfied: fastapi<1 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.116.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (1.31.1)
# Requirement already satisfied: packaging<26 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (5.29.5)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (4.15.0)
# Requirement already satisfied: uvicorn<1 in c:\users\manpr\anaconda3\lib\site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.35.0)
# Requirement already satisfied: Mako in c:\users\manpr\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict) (1.3.10)
# Requirement already satisfied: tomli in c:\users\manpr\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict) (2.2.1)
# Requirement already satisfied: colorama in c:\users\manpr\anaconda3\lib\site-packages (from click->lazypredict) (0.4.6)
# Requirement already satisfied: cffi>=1.14 in c:\users\manpr\anaconda3\lib\site-packages (from cryptography<46,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in c:\users\manpr\anaconda3\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (2.40.3)
# Requirement already satisfied: pywin32>=304 in c:\users\manpr\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\manpr\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (2.5.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\manpr\anaconda3\lib\site-packages (from fastapi<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.47.3)
# Requirement already satisfied: Werkzeug>=2.3.7 in c:\users\manpr\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\manpr\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\manpr\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\manpr\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\manpr\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\manpr\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\manpr\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\manpr\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\manpr\anaconda3\lib\site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\manpr\anaconda3\lib\site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\manpr\anaconda3\lib\site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\manpr\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\manpr\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\manpr\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manpr\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\manpr\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\manpr\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\manpr\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (3.2.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\manpr\anaconda3\lib\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in c:\users\manpr\anaconda3\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.52b1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manpr\anaconda3\lib\site-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manpr\anaconda3\lib\site-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\manpr\anaconda3\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\manpr\anaconda3\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\manpr\anaconda3\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\manpr\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow>=2.0.0->lazypredict) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\manpr\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manpr\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manpr\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\manpr\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.6.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\manpr\anaconda3\lib\site-packages (from scikit-learn->lazypredict) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\manpr\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->lazypredict) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\manpr\anaconda3\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (4.10.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\manpr\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\manpr\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (1.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\manpr\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\manpr\anaconda3\lib\site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.23)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\manpr\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (1.17.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manpr\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow>=2.0.0->lazypredict) (3.0.2)

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

data = load_breast_cancer()
X = data.data
y= data.target

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.30,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 254, number of negative: 144
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000457 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3976
# [LightGBM] [Info] Number of data points in the train set: 398, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.638191 -> initscore=0.567521
# [LightGBM] [Info] Start training from score 0.567521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# SVC                                0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# RidgeClassifier                    0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.98               0.98     0.98      0.98
# AdaBoostClassifier                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.97     0.97      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.96               0.96     0.96      0.96
# BaggingClassifier                  0.95               0.95     0.95      0.95
# ExtraTreeClassifier                0.96               0.95     0.95      0.96
# GaussianNB                         0.96               0.95     0.95      0.96
# DummyClassifier                    0.60               0.50     0.50      0.45
#
#                                Time Taken
# Model
# LogisticRegression                   0.03
# SGDClassifier                        0.01
# LinearSVC                            0.02
# Perceptron                           0.02
# SVC                                  0.02
# RandomForestClassifier               0.27
# ExtraTreesClassifier                 0.17
# RidgeClassifier                      0.02
# QuadraticDiscriminantAnalysis        0.01
# AdaBoostClassifier                   0.23
# KNeighborsClassifier                 1.89
# LinearDiscriminantAnalysis           0.03
# CalibratedClassifierCV               0.05
# LGBMClassifier                       0.12
# XGBClassifier                        0.09
# BernoulliNB                          0.02
# RidgeClassifierCV                    0.02
# PassiveAggressiveClassifier          0.03
# DecisionTreeClassifier               0.02
# LabelPropagation                     0.03
# LabelSpreading                       0.03
# NuSVC                                0.01
# NearestCentroid                      0.02
# BaggingClassifier                    0.08
# ExtraTreeClassifier                  0.02
# GaussianNB                           0.02
# DummyClassifier                      0.02

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# SVC                                0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# RidgeClassifier                    0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.98               0.98     0.98      0.98
# AdaBoostClassifier                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.97     0.97      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.96               0.96     0.96      0.96
# BaggingClassifier                  0.95               0.95     0.95      0.95
# ExtraTreeClassifier                0.96               0.95     0.95      0.96
# GaussianNB                         0.96               0.95     0.95      0.96
# DummyClassifier                    0.60               0.50     0.50      0.45
#
#                                Time Taken
# Model
# LogisticRegression                   0.03
# SGDClassifier                        0.01
# LinearSVC                            0.02
# Perceptron                           0.02
# SVC                                  0.02
# RandomForestClassifier               0.27
# ExtraTreesClassifier                 0.17
# RidgeClassifier                      0.02
# QuadraticDiscriminantAnalysis        0.01
# AdaBoostClassifier                   0.23
# KNeighborsClassifier                 1.89
# LinearDiscriminantAnalysis           0.03
# CalibratedClassifierCV               0.05
# LGBMClassifier                       0.12
# XGBClassifier                        0.09
# BernoulliNB                          0.02
# RidgeClassifierCV                    0.02
# PassiveAggressiveClassifier          0.03
# DecisionTreeClassifier               0.02
# LabelPropagation                     0.03
# LabelSpreading                       0.03
# NuSVC                                0.01
# NearestCentroid                      0.02
# BaggingClassifier                    0.08
# ExtraTreeClassifier                  0.02
# GaussianNB                           0.02
# DummyClassifier                      0.02

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# California housing dataset (recommended replacement)
california = datasets.fetch_california_housing(as_frame=True)
X, y = california.data, california.target

X, y = shuffle(X, y, random_state=13)


offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]

# %%
models

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()

# %%
X=df.drop('survived',axis=1)
y=df.iloc[:,0]

# %%
X.head()

# %%
y

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=False, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

# %%
print(models)

# %%
models
